# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Generate a sample data

# %%
np.random.seed(40)
data = pd.DataFrame({
    'feature1': np.random.rand(100),
    'feature2': np.random.rand(100)*2,
    'feature3': np.random.rand(100)*3,
    'feature4': np.random.rand(100)*4,
    'feature5': np.random.rand(100)*5
})

# Calculating the correlation matrix
correlation_matrix = data.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # *Linear Regression*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Setting the random seed for reproducibility
np.random.seed(42)
X = 3* np.random.rand(100, 1)            # Features
Y = 3+ 3*X+ np.random.rand(100, 1)       # Target

# Creating the DataFrame
data = pd.DataFrame({
    'feature' : X.flatten(),
    'Target' : Y.flatten()
})

# Insert the training dataset
X_train, X_test, y_train, y_test = train_test_split(data[['feature']], data['Target'], test_size=0.3, random_state=41) # random_state for reproducibility, test_size for train-test split

# Training the model
model = LinearRegression()
model.fit(X_train, y_train)

# Making predictions
y_pred = model.predict(X_test) # use this to make predictions regarding the test set about the target variable

# Plotting the results
plt.figure(figsize = (10, 8))
plt.scatter(X_test, y_test, color='blue', label='Actual data')
plt.plot(X_test, y_pred, color='red',linewidth = 2, label = 'Linear Regression')  # We use linewidth to remove multiple lines and making it thicker
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Model')
plt.legend()
plt.show()

# Model coefficients
print("Intercept (b0): ", model.intercept_)  
print("Slope (b1): ", model.coef_[0])  # [0] signify the first feature

# Model evaluation
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
r2 = r2_score(y_test, y_pred)             # R-squared

print("Mean Squared Error (MSE): ", mse)
print("R-squared (R2): ", r2)
# Out:
# Intercept (b0):  3.520106752637651
# Slope (b1):  2.9832897872589927
# Mean Squared Error (MSE):  0.09339687901298445
# R-squared (R2):  0.9851894064480101

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# We use try to test out the functions
try:
    import pandas as pd
    from sklearn.model_selection import train_test_split, GridSearchCV
    from sklearn.pipeline import Pipeline
    from sklearn.compose import ColumnTransformer
    from sklearn.preprocessing import OneHotEncoder, StandardScaler
    from sklearn.impute import SimpleImputer
    from sklearn.linear_model import LogisticRegression
    print("All modules imported successfully.")
except ImportError as e:
    print(f"Import error: {e}")
# Out:
# All modules imported successfully.

# %%
# Sample dataset
data = pd.DataFrame({
    'age': [25, 30, None, 40, 45],
    'income': [50000, 60000, 70000, 80000, None],
    'gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'department': ['HR', 'Finance', 'IT', 'Marketing', 'Sales'],
    'purchased': [1, 0, 1, 0, 1]
})

required_columns = ['age', 'income', 'gender', 'department', 'purchased']
missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    print(f"Missing required columns: {missing_columns}")
else:
    print("All required columns are present.")

X = data.drop('purchased', axis=1)
y = data['purchased']

print("\nInspecting Data types: ")
print(X.dtypes)
print("\nFirst few rows of the dataset: ")
print(X.head())
# Out:
# All required columns are present.
#
# Inspecting Data types:
# age           float64
# income        float64
# gender         object
# department     object
# dtype: object
#
# First few rows of the dataset:
#     age   income  gender department
# 0  25.0  50000.0    Male         HR
# 1  30.0  60000.0  Female    Finance
# 2   NaN  70000.0  Female         IT
# 3  40.0  80000.0    Male  Marketing
# 4  45.0      NaN  Female      Sales

# %%
# Defining columns for preprocessing
numerical_features = ['age', 'income']
categorical_features = ['gender', 'department']

# %%
# Verifying that the features are correctly identified
print("Numerical features:")
print(X[numerical_features].head())
print("\nCategorical features:")
print(X[categorical_features].head())

# Check for missing numerical and categorical features
missing_numericals = [col for col in numerical_features if col not in X.columns]
missing_categoricals = [col for col in categorical_features if col not in X.columns]

if missing_numericals or missing_categoricals:
    print(f"Some features are missing from the dataset: {missing_numericals + missing_categoricals}")
    # Handle missing features (e.g., by dropping them or imputing values)
else:
    print("\nAll specified columns are present for the pipeline.")
# Out:
# Numerical features:
#     age   income
# 0  25.0  50000.0
# 1  30.0  60000.0
# 2   NaN  70000.0
# 3  40.0  80000.0
# 4  45.0      NaN
#
# Categorical features:
#    gender department
# 0    Male         HR
# 1  Female    Finance
# 2  Female         IT
# 3    Male  Marketing
# 4  Female      Sales
#
# All specified columns are present for the pipeline.
